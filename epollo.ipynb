# %%
from epollo.browser import Browser

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
# Create browser instance
browser = Browser()
# Out:
# Ollama not available: Failed to connect to Ollama. Please check that Ollama is downloaded, running and accessible. https://ollama.com/download
# Ollama is not available at http://localhost:11434. Content filtering will not work. Make sure Ollama is running.

# %%
# Screenshot from URL
screenshot_bytes = browser.take_url_screenshot(
    url="https://news.google.com",
    output_path="screenshot.png",
    width=768,
    height=2048,
    full_page=False
)

# %%
from epollo import screenshot


tiles = screenshot.crop_to_square_tiles('screenshot.png', overlap=0.3)

# %%
from vlm_demo import demo_vlm_from_file

for tile in tiles:
    news_text = demo_vlm_from_file(tile)
    print(news_text)
# Out:
# 2026-02-14 13:10:23,420 - vlm_demo - INFO - Processing ./screenshot_tile_1.png with model: qwen3-vl:2b
# 2026-02-14 13:10:52,014 - vlm_demo - INFO - Processing ./screenshot_tile_2.png with model: qwen3-vl:2b
# ============================================================
# VLM RESPONSE (qwen3-vl:2b)
# Prompt: Please read the image and extract news headlines
# ============================================================
#
# ============================================================
# True
# 2026-02-14 13:11:03,641 - vlm_demo - INFO - Processing ./screenshot_tile_3.png with model: qwen3-vl:2b
# ============================================================
# VLM RESPONSE (qwen3-vl:2b)
# Prompt: Please read the image and extract news headlines
# ============================================================
# Here are the extracted news headlines from the image, including their sources and timestamps:
#
# 1. **CTV News**
#    *Mark Carney joins hands with Canada opposition leader as he pays tribute to school...*
#    (13 hours ago)
#
# 2. **CTV News**
#    *Grieving B.C. family wants answers after call for help ends in deadly police shooting*
#    (5 hours ago)
#
# 3. **BBC**
#    *Marco Rubio speech signals US-Europe relations are bruised but still friendly*
#    (6 hours ago)
#
# 4. **CTV News**
#    *Keep documents close: Experts share tips on how to travel to the U.S. without raising red flags*
#    (8 hours ago)
# ============================================================
# True
# 2026-02-14 13:11:26,915 - vlm_demo - INFO - Processing ./screenshot_tile_4.png with model: qwen3-vl:2b
# ============================================================
# VLM RESPONSE (qwen3-vl:2b)
# Prompt: Please read the image and extract news headlines
# ============================================================
# Here are the extracted news headlines from the image:
#
# 1. **CTV News**
#    *Keep documents close: Experts share tips on how to travel to the U.S. without raising red flags*
#
# 2. **TheTravel**
#    *Canada Is Now Being Joined By Two Other Countries In Boycott Of U.S. National Parks*
#
# 3. **Global News**
#    *There are changes coming to Tim Hortons menus and stores soon*
#
# 4. **Insauga**
#    *Mall that Ontario shoppers once flocked to is now closed*
#
# 5. **CTV News**
#    *Grieving B.C. family wants and help ends in deadly police shoot*
#
# 6. **HuffPost**
#    *'Crazy Spectacle': Megyn Kelly Super Bowl Rant Is Actually P...*
# ============================================================
# True
#
# ============================================================
# VLM RESPONSE (qwen3-vl:2b)
# Prompt: Please read the image and extract news headlines
# ============================================================
#
# ============================================================
# True
