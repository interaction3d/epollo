# %%
from epollo.browser import Browser

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
# Create browser instance
browser = Browser()

# %%
# Screenshot from URL
screenshot_bytes = browser.take_url_screenshot(
    url="https://news.google.com",
    output_path="screenshot.png",
    width=768,
    height=2048,
    full_page=False
)

# %%
from epollo import screenshot


tiles = screenshot.crop_to_square_tiles('screenshot.png', overlap=0.3)

# %%
from vlm_demo import demo_vlm_from_file

for tile in tiles:
    news_text = demo_vlm_from_file(tile, "Please read this image and extract news content")
    print(news_text)
# Out:
# 2026-02-14 16:58:36,759 - vlm_demo - INFO - Processing ./screenshot_tile_1.png with model: qwen3-vl:2b
# 2026-02-14 16:59:03,710 - vlm_demo - INFO -
# ============================================================
# 2026-02-14 16:59:03,710 - vlm_demo - INFO - VLM RESPONSE (qwen3-vl:2b)
# 2026-02-14 16:59:03,710 - vlm_demo - INFO - Prompt: Please read this image and extract news content
# 2026-02-14 16:59:03,710 - vlm_demo - INFO - ============================================================
# 2026-02-14 16:59:03,711 - vlm_demo - INFO - Here is the extracted news content from the provided Google News image:
#
# ---
#
# ### **1. Article from The Guardian**
# - **Headline**: *Mark Carney joins hands with Canada opposition leader as he pays tribute to school...*
# - **Source**: The Guardian
# - **Time**: 17 hours ago
# - **Author**: Leyland Cecco
# - **Summary**: Mark Carney (a former UK Chancellor) joins Canada’s opposition leader to pay tribute to a school.
#
# ---
#
# ### **2. Article from The Globe and Mail**
# - **Headline**: *Canadians will always be with you, Carney tells grieving Tumbler Ridge*
# - **Source**: The Globe and Mail
# - **Time**: 19 hours ago
# - **Authors**: Jesse Winter, Alana Smith, etc.
# - **Summary**: Carney addresses grieving survivors of the Tumbler Ridge incident.
#
# ---
#
# ### **3. Article from National Post**
# - **Headline**: *Still a long road for my Maya moon: Tumbler Ridge survivor's mom says swelling going down*
# - **Source**: National Post
# - **Time**: 6 hours ago
# - **Author**: Stewart Lewis
# - **Summary**: A Tumbler Ridge survivor’s mother discusses the ongoing challenges of the Maya moon (likely a reference to a local event or community issue).
#
# ---
#
# ### **Additional Notes**
# - The page also includes a "Picks
# 2026-02-14 16:59:03,711 - vlm_demo - INFO - ============================================================
# 2026-02-14 16:59:03,711 - vlm_demo - INFO - Processing ./screenshot_tile_2.png with model: qwen3-vl:2b
# True
# 2026-02-14 16:59:30,798 - vlm_demo - INFO -
# ============================================================
# 2026-02-14 16:59:30,799 - vlm_demo - INFO - VLM RESPONSE (qwen3-vl:2b)
# 2026-02-14 16:59:30,799 - vlm_demo - INFO - Prompt: Please read this image and extract news content
# 2026-02-14 16:59:30,799 - vlm_demo - INFO - ============================================================
# 2026-02-14 16:59:30,799 - vlm_demo - INFO -
# 2026-02-14 16:59:30,799 - vlm_demo - INFO - ============================================================
# 2026-02-14 16:59:30,800 - vlm_demo - INFO - Processing ./screenshot_tile_3.png with model: qwen3-vl:2b
# True
# 2026-02-14 16:59:57,714 - vlm_demo - INFO -
# ============================================================
# 2026-02-14 16:59:57,714 - vlm_demo - INFO - VLM RESPONSE (qwen3-vl:2b)
# 2026-02-14 16:59:57,714 - vlm_demo - INFO - Prompt: Please read this image and extract news content
# 2026-02-14 16:59:57,715 - vlm_demo - INFO - ============================================================
# 2026-02-14 16:59:57,715 - vlm_demo - INFO - Here is the extracted news content from the image, organized by source and headline:
#
# ### 1. **CBC**
# - **Headline**: Alexei Navalny was poisoned by Kremlin with dart frog toxin, European nations say
# - **Timestamp**: 4 hours ago
#
# ### 2. **The Guardian**
# - **Headline**: US pressure on Greenland is ‘totally unacceptable’, says Danish PM – Europe live
# - **Timestamp**: 14 hours ago
#
# ### 3. **TSN**
# - **Headline**: Homan has rock pulled after controversial delivery violation called on Canadian skip
# - **Timestamp**: 3 hours ago
#
# ### 4. **Global News**
# - **Headline**: There are changes coming to menus and stores soon
# - **Timestamp**: Yesterday
#
# ### 5. **CBC**
# - **Headline**: Take the tunnel. Windsor city council says as...
# - **Timestamp**: (Partially visible; context suggests a news item about Windsor city council)
#
# ### 6. **HuffPost**
# - **Headline**: 'Crazy Spectacle': Mevyn Kell...
# - **Timestamp**: (Partially visible; context suggests a news item about Mevyn Kell)
#
# Each entry includes the source, headline, and timestamp (where available). The "More news" section below also contains additional articles (e.g., from TSN, Global News, and HuffPost), though some details are partially truncated in the image.
# 2026-02-14 16:59:57,715 - vlm_demo - INFO - ============================================================
# 2026-02-14 16:59:57,715 - vlm_demo - INFO - Processing ./screenshot_tile_4.png with model: qwen3-vl:2b
# True
# 2026-02-14 17:00:25,067 - vlm_demo - INFO -
# ============================================================
# 2026-02-14 17:00:25,067 - vlm_demo - INFO - VLM RESPONSE (qwen3-vl:2b)
# 2026-02-14 17:00:25,067 - vlm_demo - INFO - Prompt: Please read this image and extract news content
# 2026-02-14 17:00:25,068 - vlm_demo - INFO - ============================================================
# 2026-02-14 17:00:25,068 - vlm_demo - INFO -
# 2026-02-14 17:00:25,068 - vlm_demo - INFO - ============================================================
# True
