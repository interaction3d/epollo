# %%
from epollo.browser import Browser

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
# Create browser instance
browser = Browser()

# %%
# Screenshot from URL
screenshot_bytes = browser.take_url_screenshot(
    url="https://news.google.com",
    output_path="screenshot.png",
    width=768,
    height=768,
    full_page=False
)
# Out:
# 2026-02-14 12:34:03,813 - epollo.screenshot - INFO - Screenshot renderer started successfully
# 2026-02-14 12:34:09,793 - epollo.screenshot - INFO - Screenshot saved to screenshot.png
# 2026-02-14 12:34:09,862 - epollo.screenshot - INFO - Screenshot renderer stopped

# %%
from vlm_demo import demo_vlm_from_file

demo_vlm_from_file("screenshot.png")
# Out:
# 2026-02-14 12:46:16,103 - vlm_demo - INFO - Processing screenshot.png with model: qwen3-vl:2b
# ============================================================
# VLM RESPONSE (qwen3-vl:2b)
# Prompt: Please read the image and extract news headlines
# ============================================================
# Here are the extracted news headlines from the image:
#
# 1. **Tumbler Ridge mass shooting**
#    *Questions linger around the Tumbler Ridge shooter’s access to guns*
#    (Source: The Globe and Mail)
#
# 2. **Mark Carney joins hands with Canada opposition leader as he pays tribute to school...**
#    (Source: The Guardian)
#
# 3. **What is B.C.’s Mental Health Act and why is it relevant to Tumbler Ridge shooting?**
#    (Source: CityNews Montreal)
#
# 4. **At peace to have my son buried in my country: Father of Tumbler Ridge shooting victim prepares to bury son in Zambia**
#    (Source: CTV News)
# ============================================================
# True
