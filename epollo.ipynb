# %%
from epollo.browser import Browser

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
# Create browser instance
browser = Browser()
# Out:
# Ollama not available: Failed to connect to Ollama. Please check that Ollama is downloaded, running and accessible. https://ollama.com/download
# Ollama is not available at http://localhost:11434. Content filtering will not work. Make sure Ollama is running.

# %%
# Screenshot from URL
screenshot_bytes = browser.take_url_screenshot(
    url="https://news.google.com",
    output_path="screenshot.png",
    width=1200,
    height=800,
    full_page=True
)

# %%
screenshot_bytes = browser.take_url_screenshot(
    url="https://www.foxnews.com",
    output_path="screenshot.png",
    width=1200,
    height=800,
    full_page=True
)
# Out:
# networkidle failed, trying domcontentloaded: Page.goto: Timeout 30000ms exceeded.
# Call log:
#   - navigating to "https://www.foxnews.com/", waiting until "networkidle"

# %%
screenshot_bytes = browser.take_url_screenshot(
    url="https://www.nytimes.com/",
    output_path="screenshot.png",
    width=1200,
    height=800,
    full_page=True
)

# %%
screenshot_bytes = browser.take_url_screenshot(
    url="https://www.cnn.com/",
    output_path="screenshot.png",
    width=1200,
    height=800,
    full_page=True
)

# %%
screenshot_bytes = browser.take_url_screenshot(
    url="https://globalnews.ca/",
    output_path="screenshot.png",
    width=1200,
    height=800,
    full_page=True
)

# %%
screenshot_bytes = browser.take_url_screenshot(
    url="https://www.ctvnews.ca/",
    output_path="screenshot.png",
    width=1200,
    height=800,
    full_page=True
)
